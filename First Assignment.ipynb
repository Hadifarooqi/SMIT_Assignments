# %%
### Print your name
name = "Hadi Farooqi"
print(name)
# Out:
# Hadi Farooqi

# %%
### Print your age and city on separate lines
age = 19
city = "Karachi"

print(age)
print(city)
# Out:
# 19
# Karachi

# %%
### Print the sentence:
sentence = "Python is strongly type language"
print(sentence)
# Out:
# Python is strongly type language

# %%
### Print your name,age and country in a single line
name = "Hadi Farooqi"
age = 19
country = "Pakistan"

print(name,",",age,",",country)
# Out:
# Hadi Farooqi , 19 , Pakistan

# %%
### Print three numbers in one line separated by spaces
num1 = 10
num2 = 20
num3 = 30

print(num1,num2,num3)
# Out:
# 10 20 30

# %%
### Print apple,banana,mango separated by |
fruit1 = "Apple"
fruit2 = "Banana"
fruit3 = "Mango"

print(fruit1,fruit2,fruit3,sep="|")
# Out:
# Apple|Banana|Mango

# %%
### Create a variable name and print it
name = "Hadi"
print(name)
# Out:
# Hadi

# %%
### Create a variable age and print it
age = 20
print(age)
# Out:
# 20

# %%
### Create a variable city,change its value,and print before & after
city = "Karachi"
print("Before Change:",city)

city = "Hyderabad"
print("After Change:", city)
# Out:
# Before Change: Karachi
# After Change: Hyderabad

# %%
### Create variable x and y and print their sum
x = 5
y = 7
sum = x + y
print("Sum:", sum)
# Out:
# Sum: 12

# %%
### Assign result of 7 * 8 to a variable and print it
result = 7 * 8
print(result)
# Out:
# 56

# %%
### Assign an integer and float,print their types
x = 10
y = 2.5

print("Type of x:",type(x))
print("Type of y:",type(y))
# Out:
# Type of x: <class 'int'>
# Type of y: <class 'float'>

# %%
### Assign True to a variable and print it
is_active = True
print(is_active)
# Out:
# True

# %%
### Assign 100 to x,y,z in a single line and print
x = y = z = 100
print(x,y,z)
# Out:
# 100 100 100

# %%
### Assign 3.14 to variable pi and print its type
pi = 3.14
print("Type of pi:",type(pi))
# Out:
# Type of pi: <class 'float'>
